# %% [markdown]
# # Practical Geoplotting using Folium: A Beginner's Course with Real-life Examples
#
# Welcome to this practical guide on using Folium for geoplotting! This course is designed to walk you through real-life examples and code snippets to help you create interactive maps for various applications.
#
# ---
#
# ## Table of Contents
# 1. [Introduction to Folium](#introduction-to-folium)
# 2. [Setting Up Your Environment](#setting-up-your-environment)
# 3. [Creating Your First Map](#creating-your-first-map)
# 4. [Working with Markers](#working-with-markers)
# 5. [Choropleth Maps](#choropleth-maps)
# 6. [Heatmaps](#heatmaps)
# 7. [GeoJSON Integration](#geojson-integration)
# 8. [Real-life Project 1: Plotting Crime Data](#real-life-project-1-plotting-crime-data)
# 9. [Real-life Project 2: Visualizing Real Estate Data](#real-life-project-2-visualizing-real-estate-data)
# 10. [Real-life Project 3: Creating a Travel Itinerary Map](#real-life-project-3-creating-a-travel-itinerary-map)
# 11. [Further Resources](#further-resources)
#
# ---
#
# ## Introduction to Folium
#
# Folium is a powerful Python library that helps you create interactive maps. It is built on top of the Leaflet.js JavaScript library, providing interactive map features while allowing you to work entirely in Python.
#
# ### Why Use Folium?
# - **Interactive Mapping:** Create interactive maps directly from Python.
# - **Geospatial Data Visualization:** Effectively visualize geospatial data.
# - **Multiple Layers:** Easily add various layers and data overlays.
# - **Integration:** Seamlessly integrate with data analysis workflows.
# - **Exportable Maps:** Export standalone HTML files for sharing.
#
# ---
#
# ### Setting Up Your Environment
#
# Before diving into mapping, ensure that you have the necessary tools installed:
#
# 1. **Python 3.x:** Ensure you have a recent version of Python.
# 2. **Folium Library:** Install Folium using pip:
#    ```bash
#    pip install folium

# %%
# Install required packages
# You can run this in your Jupyter notebook or terminal
#!pip install folium pandas numpy matplotlib

# Import the libraries we'll use throughout the course
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  ### Creating Your First Map
# Let's create a simple map to get started.

# %%
# Create a basic map centered on a specific location
# Parameters: location=[latitude, longitude], zoom_start=zoom level
my_map = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2be0f0af2196b4f1391ea1a7b3826d07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2be0f0af2196b4f1391ea1a7b3826d07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2be0f0af2196b4f1391ea1a7b3826d07 = L.map(
#                 &quot;map_2be0f0af2196b4f1391ea1a7b3826d07&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51815667a1150cf2b0afddbc473be6c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51815667a1150cf2b0afddbc473be6c1.addTo(map_2be0f0af2196b4f1391ea1a7b3826d07);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Map Tiles
# Folium supports various map styles through different tile providers.

# %%
# Different map tile styles
map_tiles = {
    'OpenStreetMap': folium.Map(location=[37.7749, -122.4194], zoom_start=12, tiles='OpenStreetMap'),
    'Stamen Terrain': folium.Map(location=[37.7749, -122.4194], zoom_start=12, tiles='Stamen Terrain'),
    'Stamen Toner': folium.Map(location=[37.7749, -122.4194], zoom_start=12, tiles='Stamen Toner'),
    'Cartodb Positron': folium.Map(location=[37.7749, -122.4194], zoom_start=12, tiles='CartoDB positron')
}

# You can display any of these maps
map_tiles['Cartodb Positron']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc31b94ade0347cd6361a47d2e9320b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc31b94ade0347cd6361a47d2e9320b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc31b94ade0347cd6361a47d2e9320b6 = L.map(
#                 &quot;map_dc31b94ade0347cd6361a47d2e9320b6&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a19db6abcb0546fc173b59fd3168335 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a19db6abcb0546fc173b59fd3168335.addTo(map_dc31b94ade0347cd6361a47d2e9320b6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Saving Maps

# %%
# Save the map to an HTML file
my_map.save('my_first_map.html')

# %% [markdown]
# ### Working with Markers
# Markers are used to highlight specific locations on your map.

# %%
# Create a map centered on San Francisco
sf_map = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Add a simple marker
folium.Marker(
    location=[37.7749, -122.4194],
    popup='San Francisco',
    tooltip='Click for more info'
).add_to(sf_map)

# Display the map
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ce6b25b5806b840cc442ca5aff8ba8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ce6b25b5806b840cc442ca5aff8ba8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ce6b25b5806b840cc442ca5aff8ba8a = L.map(
#                 &quot;map_6ce6b25b5806b840cc442ca5aff8ba8a&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_110b1829ce0300caa3ac1e8601029305 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_110b1829ce0300caa3ac1e8601029305.addTo(map_6ce6b25b5806b840cc442ca5aff8ba8a);
#
#
#             var marker_b3701c552d8f0d8687ce24bec2d3b23a = L.marker(
#                 [37.7749, -122.4194],
#                 {
# }
#             ).addTo(map_6ce6b25b5806b840cc442ca5aff8ba8a);
#
#
#         var popup_c735d3f2f0d4fa47d1f1235a142eb5ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8de50d5adf560d7b17fecb433eb854c1 = $(`&lt;div id=&quot;html_8de50d5adf560d7b17fecb433eb854c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_c735d3f2f0d4fa47d1f1235a142eb5ef.setContent(html_8de50d5adf560d7b17fecb433eb854c1);
#
#
#
#         marker_b3701c552d8f0d8687ce24bec2d3b23a.bindPopup(popup_c735d3f2f0d4fa47d1f1235a142eb5ef)
#         ;
#
#
#
#
#             marker_b3701c552d8f0d8687ce24bec2d3b23a.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Custom Markers
# You can customize markers with different icons and colors.

# %%
# Create a map
custom_marker_map = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Add a marker with a custom icon
folium.Marker(
    location=[37.7749, -122.4194],
    popup='San Francisco',
    tooltip='Click for more info',
    icon=folium.Icon(color='green', icon='info-sign')
).add_to(custom_marker_map)

# Add another marker with a different icon
folium.Marker(
    location=[37.7833, -122.4167],
    popup='Union Square',
    tooltip='Shopping District',
    icon=folium.Icon(color='red', icon='shopping-cart', prefix='fa')
).add_to(custom_marker_map)

# Display the map
custom_marker_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8bc5a6f8b5f564ff32c7f36dd57dd1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8bc5a6f8b5f564ff32c7f36dd57dd1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8bc5a6f8b5f564ff32c7f36dd57dd1a = L.map(
#                 &quot;map_e8bc5a6f8b5f564ff32c7f36dd57dd1a&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcaebe69524db9edf8f2fb9d97540da7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcaebe69524db9edf8f2fb9d97540da7.addTo(map_e8bc5a6f8b5f564ff32c7f36dd57dd1a);
#
#
#             var marker_a56c4452b7838413f91c5ef2160b39a4 = L.marker(
#                 [37.7749, -122.4194],
#                 {
# }
#             ).addTo(map_e8bc5a6f8b5f564ff32c7f36dd57dd1a);
#
#
#             var icon_b0c407921e4a2f4b29486a43bbabb9ee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_125ef7f608c94b2af0f4252871b24347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1fdce0cb5d497d89c1fb73944654906 = $(`&lt;div id=&quot;html_e1fdce0cb5d497d89c1fb73944654906&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_125ef7f608c94b2af0f4252871b24347.setContent(html_e1fdce0cb5d497d89c1fb73944654906);
#
#
#
#         marker_a56c4452b7838413f91c5ef2160b39a4.bindPopup(popup_125ef7f608c94b2af0f4252871b24347)
#         ;
#
#
#
#
#             marker_a56c4452b7838413f91c5ef2160b39a4.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a56c4452b7838413f91c5ef2160b39a4.setIcon(icon_b0c407921e4a2f4b29486a43bbabb9ee);
#
#
#             var marker_70d41022338bef4f2f8b0be4c0cbcb0f = L.marker(
#                 [37.7833, -122.4167],
#                 {
# }
#             ).addTo(map_e8bc5a6f8b5f564ff32c7f36dd57dd1a);
#
#
#             var icon_96ab2c840bff5e00b446a3ccda20f086 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;shopping-cart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bd58d7fbaacdd43b732d1123590a31c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb26ce94839d53b41db866fa3bba2a5e = $(`&lt;div id=&quot;html_eb26ce94839d53b41db866fa3bba2a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Union Square&lt;/div&gt;`)[0];
#                 popup_bd58d7fbaacdd43b732d1123590a31c1.setContent(html_eb26ce94839d53b41db866fa3bba2a5e);
#
#
#
#         marker_70d41022338bef4f2f8b0be4c0cbcb0f.bindPopup(popup_bd58d7fbaacdd43b732d1123590a31c1)
#         ;
#
#
#
#
#             marker_70d41022338bef4f2f8b0be4c0cbcb0f.bindTooltip(
#                 `&lt;div&gt;
#                      Shopping District
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_70d41022338bef4f2f8b0be4c0cbcb0f.setIcon(icon_96ab2c840bff5e00b446a3ccda20f086);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Circle Markers
# Circle markers are useful for showing areas of influence.
# python

# %%
# Create a map
circle_map = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Add a circle marker
folium.CircleMarker(
    location=[37.7749, -122.4194],
    radius=100,  # radius in pixels
    popup='San Francisco',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(circle_map)

# Display the map
circle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_815c6bc3672d9babee05e8f6a35f22cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_815c6bc3672d9babee05e8f6a35f22cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_815c6bc3672d9babee05e8f6a35f22cf = L.map(
#                 &quot;map_815c6bc3672d9babee05e8f6a35f22cf&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b8d7eb006f780e13f6afcdcb8a007dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b8d7eb006f780e13f6afcdcb8a007dd.addTo(map_815c6bc3672d9babee05e8f6a35f22cf);
#
#
#             var circle_marker_422045469b231be5c8550cf4f5e71433 = L.circleMarker(
#                 [37.7749, -122.4194],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_815c6bc3672d9babee05e8f6a35f22cf);
#
#
#         var popup_66e8203579d8105b3587a3a9967060b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6408879aac729d20f630dc9bfc63d398 = $(`&lt;div id=&quot;html_6408879aac729d20f630dc9bfc63d398&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_66e8203579d8105b3587a3a9967060b6.setContent(html_6408879aac729d20f630dc9bfc63d398);
#
#
#
#         circle_marker_422045469b231be5c8550cf4f5e71433.bindPopup(popup_66e8203579d8105b3587a3a9967060b6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Choropleth Maps
# Choropleth maps use color intensity to show value differences across geographic areas.

# %%
import pandas as pd
import folium

# Use the URL for the GeoJSON file of US state boundaries.
state_geo = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json'

# Create sample unemployment data.
state_unemployment = pd.DataFrame({
    'State': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 
              'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
              'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 
              'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
              'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 
              'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 
              'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 
              'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
              'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 
              'West Virginia', 'Wisconsin', 'Wyoming'],
    'Unemployment': [7.1, 6.8, 8.1, 7.2, 9.3, 7.5, 8.2, 7.8, 8.7, 8.3, 6.5, 6.9, 
                     9.1, 8.5, 6.2, 6.7, 8.0, 7.4, 7.6, 7.2, 7.8, 9.0, 6.5, 
                     8.8, 7.7, 6.3, 5.9, 10.2, 6.1, 8.4, 7.9, 8.1, 8.7, 5.2, 
                     8.5, 6.8, 8.5, 8.2, 9.0, 9.1, 5.5, 8.4, 7.2, 6.4, 6.0, 
                     6.9, 8.0, 8.5, 7.2, 5.6]
})

# Create a choropleth map.
choropleth_map = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_unemployment,
    columns=['State', 'Unemployment'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
).add_to(choropleth_map)

folium.LayerControl().add_to(choropleth_map)

# Display the map (this works in a Jupyter Notebook).
choropleth_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85bbaa3874668030270b217e49b5df6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85bbaa3874668030270b217e49b5df6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85bbaa3874668030270b217e49b5df6a = L.map(
#                 &quot;map_85bbaa3874668030270b217e49b5df6a&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8cd1206abcf5a26d4420b2e0a570647 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8cd1206abcf5a26d4420b2e0a570647.addTo(map_85bbaa3874668030270b217e49b5df6a);
#
#
#             var choropleth_cdc4275bffa4d39044614b2a4df4d197 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_15770cc8edc521ae145f33ac6c7623ee_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;ID&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;TX&quot;: case &quot;VA&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;HI&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;MN&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;OK&quot;: case &quot;UT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;GA&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MA&quot;: case &quot;MO&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;OH&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;TN&quot;: case &quot;WA&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;FL&quot;: case &quot;IL&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NC&quot;: case &quot;RI&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;: case &quot;SD&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_15770cc8edc521ae145f33ac6c7623ee_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_15770cc8edc521ae145f33ac6c7623ee = L.geoJson(null, {
#                 onEachFeature: geo_json_15770cc8edc521ae145f33ac6c7623ee_onEachFeature,
#
#                 style: geo_json_15770cc8edc521ae145f33ac6c7623ee_styler,
#             ...{
# }
#         });
#
#         function geo_json_15770cc8edc521ae145f33ac6c7623ee_add (data) {
#             geo_json_15770cc8edc521ae145f33ac6c7623ee
#                 .addData(data);
#         }
#             geo_json_15770cc8edc521ae145f33ac6c7623ee_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88

# %% [markdown]
# ### Heatmaps
# Heatmaps are excellent for visualizing density of points.

# %%
# Install the folium plugin for heatmaps
# !pip install folium.plugins

# Import the heatmap plugin
from folium.plugins import HeatMap

# Create some sample data - latitude and longitude pairs
# This could represent crime incidents, customer locations, etc.
data = [
    [37.7749, -122.4194, 0.5],  # [lat, lon, intensity]
    [37.7749, -122.4294, 0.7],
    [37.7849, -122.4394, 0.4],
    [37.7749, -122.4494, 0.8],
    [37.7649, -122.4594, 0.2],
    [37.7549, -122.4694, 0.9],
    [37.7449, -122.4794, 0.5],
    [37.7349, -122.4894, 0.3]
]

# Create a map
heat_map = folium.Map(location=[37.7749, -122.4194], zoom_start=13)

# Add a heatmap layer
HeatMap(data).add_to(heat_map)

# Display the map
heat_map
# Out:
# ERROR: Could not find a version that satisfies the requirement folium.plugins (from versions: none)
# ERROR: No matching distribution found for folium.plugins
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7daf3384b25d47f2e4d1f9cdaadcadd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7daf3384b25d47f2e4d1f9cdaadcadd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7daf3384b25d47f2e4d1f9cdaadcadd = L.map(
#                 &quot;map_f7daf3384b25d47f2e4d1f9cdaadcadd&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7077185d280933019520eda00227a508 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7077185d280933019520eda00227a508.addTo(map_f7daf3384b25d47f2e4d1f9cdaadcadd);
#
#
#             var heat_map_6236f74293a908528b0cb1c133dca337 = L.heatLayer(
#                 [[37.7749, -122.4194, 0.5], [37.7749, -122.4294, 0.7], [37.7849, -122.4394, 0.4], [37.7749, -122.4494, 0.8], [37.7649, -122.4594, 0.2], [37.7549, -122.4694, 0.9], [37.7449, -122.4794, 0.5], [37.7349, -122.4894, 0.3]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_6236f74293a908528b0cb1c133dca337.addTo(map_f7daf3384b25d47f2e4d1f9cdaadcadd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### GeoJSON Integration
# GeoJSON is a format for encoding geographic data structures.
# python

# %%
# Create a map
geojson_map = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Sample GeoJSON data - a polygon representing an area
sample_geojson = {
    "type": "Feature",
    "properties": {
        "name": "Financial District",
        "amenity": "Business District",
        "popupContent": "San Francisco's Financial District"
    },
    "geometry": {
        "type": "Polygon",
        "coordinates": [
            [
                [-122.4056, 37.7934],
                [-122.4056, 37.7824],
                [-122.3946, 37.7824],
                [-122.3946, 37.7934],
                [-122.4056, 37.7934]
            ]
        ]
    }
}

# Add the GeoJSON to the map
folium.GeoJson(
    sample_geojson,
    name='Financial District',
    style_function=lambda x: {'fillColor': '#ffff00', 'color': '#000000'}
).add_to(geojson_map)

# Display the map
geojson_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bef76e76ea0dac97b0f4657892eb921d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bef76e76ea0dac97b0f4657892eb921d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bef76e76ea0dac97b0f4657892eb921d = L.map(
#                 &quot;map_bef76e76ea0dac97b0f4657892eb921d&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cb395750f1f86de85f2d11f4fba956e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cb395750f1f86de85f2d11f4fba956e.addTo(map_bef76e76ea0dac97b0f4657892eb921d);
#
#
#         function geo_json_8b6da187c0e07d60e39285497ebf7b67_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;#000000&quot;, &quot;fillColor&quot;: &quot;#ffff00&quot;};
#             }
#         }
#
#         function geo_json_8b6da187c0e07d60e39285497ebf7b67_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b6da187c0e07d60e39285497ebf7b67 = L.geoJson(null, {
#                 onEachFeature: geo_json_8b6da187c0e07d60e39285497ebf7b67_onEachFeature,
#
#                 style: geo_json_8b6da187c0e07d60e39285497ebf7b67_styler,
#             ...{
# }
#         });
#
#         function geo_json_8b6da187c0e07d60e39285497ebf7b67_add (data) {
#             geo_json_8b6da187c0e07d60e39285497ebf7b67
#                 .addData(data);
#         }
#             geo_json_8b6da187c0e07d60e39285497ebf7b67_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.4056, 37.7934], [-122.4056, 37.7824], [-122.3946, 37.7824], [-122.3946, 37.7934], [-122.4056, 37.7934]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;Business District&quot;, &quot;name&quot;: &quot;Financial District&quot;, &quot;popupContent&quot;: &quot;San Francisco\u0027s Financial District&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_8b6da187c0e07d60e39285497ebf7b67.addTo(map_bef76e76ea0dac97b0f4657892eb921d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Real-life Project 1: Plotting Crime Data
# Let's create a map that visualizes crime data in a city.

# %%
# Generate sample crime data
# In a real project, you would load this from a CSV file or API
crime_data = pd.DataFrame({
    'latitude': np.random.uniform(37.75, 37.80, 100),
    'longitude': np.random.uniform(-122.45, -122.40, 100),
    'crime_type': np.random.choice(['Theft', 'Assault', 'Burglary', 'Robbery'], 100),
    'date': pd.date_range(start='2023-01-01', periods=100, freq='D'),
    'time': pd.date_range(start='00:00:00', periods=100, freq='15min').time
})

# Create a color mapping for crime types
crime_colors = {
    'Theft': 'blue',
    'Assault': 'red',
    'Burglary': 'green',
    'Robbery': 'purple'
}

# Create a map centered on the city
crime_map = folium.Map(location=[37.77, -122.42], zoom_start=13)

# Create a marker cluster for better performance with many points
from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(crime_map)

# Add markers for each crime
for idx, row in crime_data.iterrows():
    # Create popup content
    popup_content = f"""
    <b>Crime Type:</b> {row['crime_type']}<br>
    <b>Date:</b> {row['date'].strftime('%Y-%m-%d')}<br>
    <b>Time:</b> {row['time']}
    """
    
    # Add marker to the cluster
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color=crime_colors[row['crime_type']], icon='info-sign'),
    ).add_to(marker_cluster)

# Add a heatmap layer of all crimes
heat_data = [[row['latitude'], row['longitude']] for idx, row in crime_data.iterrows()]
HeatMap(heat_data, radius=15).add_to(crime_map)

# Add layer control
folium.LayerControl().add_to(crime_map)

# Display the map
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f73c4112fc538d142a1d320fa79100c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f73c4112fc538d142a1d320fa79100c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f73c4112fc538d142a1d320fa79100c = L.map(
#                 &quot;map_5f73c4112fc538d142a1d320fa79100c&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_542eef2f7941ee0b6e917e9661a30507 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_542eef2f7941ee0b6e917e9661a30507.addTo(map_5f73c4112fc538d142a1d320fa79100c);
#
#
#             var marker_cluster_cb9e0ce80685b99364064eb94243e0f6 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_bd6158108194f7ec01a2f76d5d60304a = L.marker(
#                 [37.7907895852108, -122.4025448592652],
#                 {
# }
#             ).addTo(marker_cluster_cb9e0ce80685b99364064eb94243e0f6);
#
#
#             var icon_06ed80698172c96d9d1c044fc3b5de46 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d547e8ea0c741fabc7eb7778ada232da = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1a6aca227ef1a93d527c79b2f614b691 = $(`&lt;div id=&quot;html_1a6aca227ef1a93d527c79b2f614b691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Crime Type:&lt;/b&gt; Burglary&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2023-01-01&lt;br&gt;     &lt;b&gt;Time:&lt;/b&gt; 00:00:00     &lt;/div&gt;`)[0];
#                 popup_d547e8ea0c741fabc7eb7778ada232da.setContent(html_1a6aca227ef1a93d527c79b2f614b691);
#
#
#
#         marker_bd6158108194f7ec01a2f76d5d60304a.bindPopup(popup_d547e8ea0c741fabc7eb7778ada232da)
#         ;
#
#
#
#
#                 marker_bd6158108194f7ec01a2f76d5d60304a.setIcon(icon_06ed80698172c96d9d1c044fc3b5de46);
#
#
#             var marker_e093b7d40e76900262d8bf1091345ef8 = L.marker(
#                 [37.79938938118146, -122.43070194799239],
#                 {
# }
#             ).addTo(marker_cluster_cb9e0ce80685b99364064eb94243e0f6);
#
#
#             var icon_9e1079623c629f1cf164bdbab0152c98 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c1aec359260120c8a8bbc7aa6d5b4aa8 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2a5be79b4f1b63b017a855155f2b8923 = $(`&lt;div id=&quot;html_2a5be79b4f1b63b017a855155f2b8923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Crime Type:&lt;/b&gt; Theft&lt;br&gt;     &lt;b&gt;Date:&lt;/b&gt; 2023-01-02&lt;br&gt;     &lt;b&gt;Time:&lt;/b&gt; 00:15:00     &lt;/div&gt;`)[0];
#                 popup_c1aec359260120c8a8bbc7aa6d5b4aa8.setContent(html_2a5be79b4f1b63b017a855155f2b8923);
#
#
#
#         marker_e093b7d40e76900262d8bf1091345ef8.bindPopup(popup_c1aec359260120c8a8bbc7aa6d5b4aa8)
#         ;
#
#
#
#
#                 marker_e093b7d40e76900262d8bf1091345ef8.setIcon(icon_9e1079623c629f1cf164bdbab0152c98);
#
#
#             var marker_55a688303bc1da2155f673fd9d826d89 = L.marker(
#                 [37.77046077223046, -122.43605111035028],
#                 {
# }
#             ).addTo(marker_cluster_cb9e0ce80685b99364064eb94243e0f6);
#
#
#             var icon_9fb42c2090d54d528667b5b273054e34 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot

# %% [markdown]
# ### Real-life Project 2: Visualizing Real Estate Data
# Now let's create a map that shows real estate prices across different neighborhoods.

# %%
# Generate sample real estate data
real_estate_data = pd.DataFrame({
    'neighborhood': ['Downtown', 'Marina', 'Mission', 'Nob Hill', 'SOMA', 'Sunset'],
    'avg_price': [1200000, 1500000, 900000, 1300000, 950000, 850000],
    'latitude': [37.7749, 37.8030, 37.7600, 37.7930, 37.7790, 37.7550],
    'longitude': [-122.4194, -122.4380, -122.4190, -122.4160, -122.3990, -122.4850]
})

# Create a map
real_estate_map = folium.Map(location=[37.7749, -122.4194], zoom_start=13)

# Create a color scale based on prices
import branca.colormap as cm

# Create a color map
colormap = cm.linear.YlOrRd_09.scale(
    real_estate_data['avg_price'].min(), 
    real_estate_data['avg_price'].max()
)

# Add circles to represent each neighborhood's average price
for idx, row in real_estate_data.iterrows():
    folium.Circle(
        location=[row['latitude'], row['longitude']],
        radius=500,  # 500 meters
        popup=f"{row['neighborhood']}: ${row['avg_price']:,}",
        color=colormap(row['avg_price']),
        fill=True,
        fill_color=colormap(row['avg_price'])
    ).add_to(real_estate_map)

# Add the colormap to the map
colormap.caption = 'Average Home Price ($)'
colormap.add_to(real_estate_map)

# Display the map
real_estate_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fc2d542c988dfe7283c1f9a5305c724 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fc2d542c988dfe7283c1f9a5305c724&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fc2d542c988dfe7283c1f9a5305c724 = L.map(
#                 &quot;map_3fc2d542c988dfe7283c1f9a5305c724&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a57818692c9a81b764b3be432d92d7c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a57818692c9a81b764b3be432d92d7c8.addTo(map_3fc2d542c988dfe7283c1f9a5305c724);
#
#
#             var circle_b8ac29c4698cfd1d19991167b69f7c14 = L.circle(
#                 [37.7749, -122.4194],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fd7a36ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fd7a36ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fc2d542c988dfe7283c1f9a5305c724);
#
#
#         var popup_b957780795255b651b669230e5983d5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_319fba6929f3d6845d150ea5a64d57cd = $(`&lt;div id=&quot;html_319fba6929f3d6845d150ea5a64d57cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown: $1,200,000&lt;/div&gt;`)[0];
#                 popup_b957780795255b651b669230e5983d5b.setContent(html_319fba6929f3d6845d150ea5a64d57cd);
#
#
#
#         circle_b8ac29c4698cfd1d19991167b69f7c14.bindPopup(popup_b957780795255b651b669230e5983d5b)
#         ;
#
#
#
#
#             var circle_f0692e7c4807800064831333438a68fb = L.circle(
#                 [37.803, -122.438],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800026ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#800026ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fc2d542c988dfe7283c1f9a5305c724);
#
#
#         var popup_78794e3d51e86940c26f0b634057710d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b8f71a4a2bc14078b260fcafa0a8744 = $(`&lt;div id=&quot;html_1b8f71a4a2bc14078b260fcafa0a8744&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marina: $1,500,000&lt;/div&gt;`)[0];
#                 popup_78794e3d51e86940c26f0b634057710d.setContent(html_1b8f71a4a2bc14078b260fcafa0a8744);
#
#
#
#         circle_f0692e7c4807800064831333438a68fb.bindPopup(popup_78794e3d51e86940c26f0b634057710d)
#         ;
#
#
#
#
#             var circle_ca57c7c898973d16a578fbda5cbbbd02 = L.circle(
#                 [37.76, -122.419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff4b1ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff4b1ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fc2d542c988dfe7283c1f9a5305c724);
#
#
#         var popup_0a5aff98d2c058ce475a44eb7fc27938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ec5ee2cb496ae9203b6474d8819cee9 = $(`&lt;div id=&quot;html_6ec5ee2cb496ae9203b6474d8819cee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mission: $900,000&lt;/div&gt;`)[0];
#                 popup_0a5aff98d2c058ce475a44eb7fc27938.setContent(html_6ec5ee2cb496ae9203b6474d8819cee9);
#
#
#
#         circle_ca57c7c898973d16a578fbda5cbbbd02.bindPopup(popup_0a5aff98d2c058ce475a44eb7fc27938)
#         ;
#
#
#
#
#             var circle_17a0679ad681217d05c5e53ee8977f94 = L.circle(
#                 [37.793, -122.416],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ef3222ff&quot;, &quot;dashArray&quot;:

# %% [markdown]
# ### Real-life Project 3: Creating a Travel Itinerary Map
# Let's create a map that shows a travel itinerary with multiple destinations.
# python

# %%
# Define a travel itinerary
itinerary = pd.DataFrame({
    'place': ['Golden Gate Bridge', 'Alcatraz Island', 'Fisherman\'s Wharf', 
              'Chinatown', 'Union Square', 'Twin Peaks'],
    'day': [1, 1, 2, 2, 3, 3],
    'description': [
        'Iconic suspension bridge spanning the Golden Gate Strait',
        'Historic former federal prison on an island',
        'Popular tourist area with seafood restaurants and sea lion sightings',
        'Oldest Chinatown in North America',
        'Shopping district in downtown San Francisco',
        'Famous hills offering panoramic views of the city'
    ],
    'latitude': [37.8199, 37.8270, 37.8080, 37.7941, 37.7879, 37.7544],
    'longitude': [-122.4783, -122.4230, -122.4177, -122.4078, -122.4075, -122.4477]
})

# Create a map
itinerary_map = folium.Map(location=[37.7749, -122.4194], zoom_start=13)

# Define colors for each day
day_colors = {1: 'blue', 2: 'green', 3: 'red'}

# Add markers for each location
for idx, row in itinerary.iterrows():
    # Create popup content
    popup_content = f"""
    <b>{row['place']}</b><br>
    <b>Day:</b> {row['day']}<br>
    <b>Description:</b> {row['description']}
    """
    
    # Add marker
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color=day_colors[row['day']], icon='info-sign', prefix='fa'),
    ).add_to(itinerary_map)

# Connect the locations for each day with lines
from folium.plugins import AntPath

# For each day, create a path
for day in itinerary['day'].unique():
    # Filter locations for this day
    day_locations = itinerary[itinerary['day'] == day]
    
    # Create a list of coordinate pairs
    locations = [[row['latitude'], row['longitude']] for idx, row in day_locations.iterrows()]
    
    # Add an ant path
    AntPath(
        locations=locations,
        color=day_colors[day],
        weight=5,
        opacity=0.7
    ).add_to(itinerary_map)

# Display the map
itinerary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5229cb9ea96c760111bc8011a9ad6873 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5229cb9ea96c760111bc8011a9ad6873&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5229cb9ea96c760111bc8011a9ad6873 = L.map(
#                 &quot;map_5229cb9ea96c760111bc8011a9ad6873&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e1710ee77ad7b4b7bfaf8f822a6954b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e1710ee77ad7b4b7bfaf8f822a6954b.addTo(map_5229cb9ea96c760111bc8011a9ad6873);
#
#
#             var marker_5300d91dc6303a2a03c9a1fdd9ceb903 = L.marker(
#                 [37.8199, -122.4783],
#                 {
# }
#             ).addTo(map_5229cb9ea96c760111bc8011a9ad6873);
#
#
#             var icon_1b9782503190c53fa3d1bc6bf59e7cad = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_686b1ef6823b2d98b754549dafa74a41 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2113d96ad74a71e10a2af330e6739b81 = $(`&lt;div id=&quot;html_2113d96ad74a71e10a2af330e6739b81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Golden Gate Bridge&lt;/b&gt;&lt;br&gt;     &lt;b&gt;Day:&lt;/b&gt; 1&lt;br&gt;     &lt;b&gt;Description:&lt;/b&gt; Iconic suspension bridge spanning the Golden Gate Strait     &lt;/div&gt;`)[0];
#                 popup_686b1ef6823b2d98b754549dafa74a41.setContent(html_2113d96ad74a71e10a2af330e6739b81);
#
#
#
#         marker_5300d91dc6303a2a03c9a1fdd9ceb903.bindPopup(popup_686b1ef6823b2d98b754549dafa74a41)
#         ;
#
#
#
#
#                 marker_5300d91dc6303a2a03c9a1fdd9ceb903.setIcon(icon_1b9782503190c53fa3d1bc6bf59e7cad);
#
#
#             var marker_0dec37e79965446c07a04a59677da37f = L.marker(
#                 [37.827, -122.423],
#                 {
# }
#             ).addTo(map_5229cb9ea96c760111bc8011a9ad6873);
#
#
#             var icon_c9069004ae985c7d2f1181f078f86f66 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_20d00cc1164bf4a6293e30d1ebc86805 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_91eac8544bf45c302af71973e3164aff = $(`&lt;div id=&quot;html_91eac8544bf45c302af71973e3164aff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Alcatraz Island&lt;/b&gt;&lt;br&gt;     &lt;b&gt;Day:&lt;/b&gt; 1&lt;br&gt;     &lt;b&gt;Description:&lt;/b&gt; Historic former federal prison on an island     &lt;/div&gt;`)[0];
#                 popup_20d00cc1164bf4a6293e30d1ebc86805.setContent(html_91eac8544bf45c302af71973e3164aff);
#
#
#
#         marker_0dec37e79965446c07a04a59677da37f.bindPopup(popup_20d00cc1164bf4a6293e30d1ebc86805)
#         ;
#
#
#
#
#                 marker_0dec37e79965446c07a04a59677da37f.setIcon(icon_c9069004ae985c7d2f1181f078f86f66);
#
#
#             var marker_777de5639dec57a2fb35db29ca5f92a3 = L.marker(
#                 [37.808, -122.4177],
#                 {
# }
#             ).addTo(map_5229cb9ea96c760111bc8011a9ad6873);
#
#
#             var icon_75f4ca9ee87ac0fbe0246726e6a3aa69 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82996ac41085fabbd35fc054ffe18e88 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_068b119821b8efee9ff6b54612d6b526 = $(`&lt;div id=&quot;html_068b119821b8efee9ff6b54612d6b526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Fisherman&#x27;s Wharf&lt;/b&gt;&lt;br&gt;     &lt;b&gt;Day:&lt;/b&gt; 2&lt;br&gt;     &lt;b&gt;Description:&lt;/b&gt; Popular tourist area with seafood restaurants and sea lion sightings     &lt;/div&gt;`)[0];
#                 popup_82996ac41085fabbd35fc054ffe18e88.setContent(

# %% [markdown]
# ## Further Resources
#
# To continue learning about Folium and geospatial visualization, check out these valuable resources:
#
# - [Folium Official Documentation](https://python-visualization.github.io/folium/)
# - [Folium GitHub Repository](https://github.com/python-visualization/folium)
# - [Geospatial Data in Python with GeoPandas](https://geopandas.org/)
# - [Interactive Mapping with Folium on Kaggle](https://www.kaggle.com/)
# - [Leaflet.js Documentation](https://leafletjs.com/)
#
# ### Practice and Explore
#
# Remember, the best way to learn is by practicing with real data. Here are some tips to get started:
#
# - **Find Public Datasets:** Look for public datasets with geospatial components.
# - **Create Visualizations:** Develop maps that answer specific questions.
# - **Combine Layers:** Use different layer types to tell a comprehensive story.
# - **Export and Share:** Export your maps and share your insights with others.
